# %%
# https://towardsdatascience.com/a-simple-chatbot-in-python-with-deep-learning-3e8669997758

# %%
# Using a dictionary to represent an intents.json file

data = {'intents': [
                    {'tag' : 'greeting',
                     'patterns': ['Hello', 'How are you?', 'Hi there', 'Hi'],
                     'responses': ['Hello', 'How are you doing?', 'Greetings!', ' How do you do?']},
                    {'tag': 'age',
                     'patterns' : ['How old are you?', 'When is your birthday?', 'When were you born'],
                     'responses': ['I am 25 years old', 'I was born in 1995', 'My birthday is 28th March 1995', '28/3/1995']},
                    {"tag": "date",
                     "patterns": ["what are you doing this weekend?",
                     "do you want to hang out some time?", "what are your plans for this week"],
                     "responses": ["I am available all week", "I don't have any plans", "I am not busy"]},
                    {"tag": "name",
                     "patterns": ["what's your name?", "what are you called?", "who are you?"],
                     "responses": ["My name is Kippi", "I'm Kippi", "Kippi"]},
                    {"tag": "goodbye",
                     "patterns": [ "bye", "g2g", "see ya", "adios", "cya"],
                     "responses": ["It was nice speaking to you", "See you later", "Speak soon!"]}
]}

# %%
words = []
classes = []
doc_x = []
doc_y = []

import nltk
from nltk.stem import WordNetLemmatizer
import string
nltk.download('punkt')
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()

for intent in data['intents']:
  for pattern in intent['patterns']:
    tokens = nltk.word_tokenize(pattern) # keeps exclamation marks as seperate token
    words.extend(tokens)
    doc_x.append(pattern)
    doc_y.append(intent['tag'])

    if intent['tag'] not in classes:
      classes.append(intent['tag'])

words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]

print(words)
print(classes)

words = sorted(set(words))
classes = sorted(set(classes))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ['hello', 'how', 'are', 'you', 'hi', 'there', 'hi', 'how', 'old', 'are', 'you', 'when', 'is', 'your', 'birthday', 'when', 'were', 'you', 'born', 'what', 'are', 'you', 'doing', 'this', 'weekend', 'do', 'you', 'want', 'to', 'hang', 'out', 'some', 'time', 'what', 'are', 'your', 'plan', 'for', 'this', 'week', 'what', "'s", 'your', 'name', 'what', 'are', 'you', 'called', 'who', 'are', 'you', 'bye', 'g2g', 'see', 'ya', 'adios', 'cya']
# ['greeting', 'age', 'date', 'name', 'goodbye']

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
print(doc_x)
print(doc_y)
# Out:
# ['Hello', 'How are you?', 'Hi there', 'Hi', 'How old are you?', 'When is your birthday?', 'When were you born', 'what are you doing this weekend?', 'do you want to hang out some time?', 'what are your plans for this week', "what's your name?", 'what are you called?', 'who are you?', 'bye', 'g2g', 'see ya', 'adios', 'cya']
# ['greeting', 'greeting', 'greeting', 'greeting', 'age', 'age', 'age', 'date', 'date', 'date', 'name', 'name', 'name', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye']

# %%
out_empty = [0] * len(classes)
training = []

import numpy as np

for idx, doc in enumerate(doc_x):
  bow = []
  text = lemmatizer.lemmatize(doc.lower())
  for word in words:
    bow.append(1) if word in text else bow.append(0)
  output_row = list(out_empty)
  output_row[classes.index(doc_y[idx])] = 1

  training.append([bow, output_row])

import random

random.shuffle(training)
training = np.array(training, dtype = object)

train_x = np.array(list(training[:,0]))
train_y = np.array(list(training[:,1]))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
import tensorflow as tf

input_shape = (len(train_x[0]),)
output_shape = len(train_y[0])
epochs = 200

model = Sequential()
model.add(Dense(128, input_shape = input_shape, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation = 'relu'))
model.add(Dropout(0.3))
model.add(Dense(output_shape, activation = 'softmax'))

adam = tf.keras.optimizers.Adam(learning_rate = 0.01, decay = 1e-6)

model.compile(loss = 'categorical_crossentropy', optimizer = adam, metrics = ['accuracy'])
print(model.summary())
model.fit(train_x, train_y, epochs = 200, verbose = 1)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 128)               4864
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_13 (Dense)            (None, 64)                8256
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  dense_14 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 13,445
# Trainable params: 13,445
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 1/1 [==============================] - 1s 816ms/step - loss: 1.7368 - accuracy: 0.2778
# Epoch 2/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4651 - accuracy: 0.5000
# Epoch 3/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4656 - accuracy: 0.4444
# Epoch 4/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3110 - accuracy: 0.6667
# Epoch 5/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2182 - accuracy: 0.7778
# Epoch 6/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1153 - accuracy: 0.8333
# Epoch 7/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.9242 - accuracy: 0.8889
# Epoch 8/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7699 - accuracy: 0.8889
# Epoch 9/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7063 - accuracy: 0.9444
# Epoch 10/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5707 - accuracy: 0.9444
# Epoch 11/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5418 - accuracy: 0.9444
# Epoch 12/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5069 - accuracy: 0.8333
# Epoch 13/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2558 - accuracy: 1.0000
# Epoch 14/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3473 - accuracy: 0.9444
# Epoch 15/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2321 - accuracy: 1.0000
# Epoch 16/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2900 - accuracy: 0.8889
# Epoch 17/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1129 - accuracy: 1.0000
# Epoch 18/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2039 - accuracy: 0.8889
# Epoch 19/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0981 - accuracy: 0.9444
# Epoch 20/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1019 - accuracy: 1.0000
# Epoch 21/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1752 - accuracy: 0.9444
# Epoch 22/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0970 - accuracy: 0.9444
# Epoch 23/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1141 - accuracy: 1.0000
# Epoch 24/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 25/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 26/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0453 - accuracy: 1.0000
# Epoch 27/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 28/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0834 - accuracy: 0.9444
# Epoch 29/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 30/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1823 - accuracy: 0.9444
# Epoch 31/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 32/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 33/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0942 - accuracy: 0.9444
# Epoch 34/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 35/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0242 - accuracy: 1.0000
# Epoch 36/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 37/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0169 - accuracy: 1.0000
# Epoch 38/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 40/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 41/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 42/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0641 - accuracy: 0.9444
# Epoch 43/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1275 - accuracy: 0.9444
# Epoch 44/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 45/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 46/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 47/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 48/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 50/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1390 - accuracy: 0.9444
# Epoch 51/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 52/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 53/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 54/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 55/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 56/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 58/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 59/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 60/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 61/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 62/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 64/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0189 - accuracy: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2496 - accuracy: 0.8889
# Epoch 67/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3926e-04 - accuracy: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 7ms/step - loss: 9.2318e-04 - accuracy: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 9ms/step - loss: 5.2343e-04 - accuracy: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 9ms/step - loss: 5.6482e-04 - accuracy: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.8358e-04 - accuracy: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0235 - accuracy: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 6ms/step - loss: 4.2470e-04 - accuracy: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 6ms/step - loss: 2.7201e-04 - accuracy: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 8ms/step - loss: 7.5930e-04 - accuracy: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 9ms/step - loss: 3.3953e-04 - accuracy: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1411 - accuracy: 0.9444
# Epoch 104/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 10ms/step - loss: 6.3948e-04 - accuracy: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 6ms/step - loss: 7.2100e-04 - accuracy: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 9ms/step - loss: 6.8540e-04 - accuracy: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 12ms/step - loss: 3.2204e-04 - accuracy: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 113/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 8ms/step - loss: 6.1297e-04 - accuracy: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.2122e-04 - accuracy: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 6ms/step - loss: 5.7087e-06 - accuracy: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 12ms/step - loss: 5.7329e-04 - accuracy: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 6ms/step - loss: 9.5556e-05 - accuracy: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 7ms/step - loss: 9.9044e-04 - accuracy: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 9ms/step - loss: 4.0105e-04 - accuracy: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 22ms/step - loss: 1.1806e-04 - accuracy: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 5ms/step - loss: 2.5216e-04 - accuracy: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 5ms/step - loss: 1.4700e-04 - accuracy: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 8ms/step - loss: 9.9149e-04 - accuracy: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 16ms/step - loss: 3.4834e-04 - accuracy: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 10ms/step - loss: 9.1668e-04 - accuracy: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.3011e-04 - accuracy: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 10ms/step - loss: 9.0321e-05 - accuracy: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.5241e-04 - accuracy: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0994e-04 - accuracy: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 11ms/step - loss: 6.3201e-04 - accuracy: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 6ms/step - loss: 1.0121e-04 - accuracy: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 7ms/step - loss: 4.0905e-04 - accuracy: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 8ms/step - loss: 4.8919e-04 - accuracy: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.9079e-04 - accuracy: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.9030e-04 - accuracy: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 9ms/step - loss: 4.2604e-04 - accuracy: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2978e-04 - accuracy: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 6ms/step - loss: 3.6775e-04 - accuracy: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 10ms/step - loss: 7.5755e-05 - accuracy: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 18ms/step - loss: 1.8403e-04 - accuracy: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 15ms/step - loss: 6.4943e-04 - accuracy: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.9094e-04 - accuracy: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 6ms/step - loss: 6.5148e-04 - accuracy: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 13ms/step - loss: 3.2749e-04 - accuracy: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 6ms/step - loss: 7.2301e-04 - accuracy: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 6ms/step - loss: 9.2221e-05 - accuracy: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 6ms/step - loss: 3.0349e-04 - accuracy: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 6ms/step - loss: 3.5202e-05 - accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 11ms/step - loss: 8.3595e-05 - accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 18ms/step - loss: 2.8826e-05 - accuracy: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 12ms/step - loss: 9.9101e-05 - accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 12ms/step - loss: 7.3596e-04 - accuracy: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 6ms/step - loss: 2.6935e-04 - accuracy: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.5665e-04 - accuracy: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1349e-04 - accuracy: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1775 - accuracy: 0.9444
# Epoch 186/200
# 1/1 [==============================] - 0s 9ms/step - loss: 3.3103e-04 - accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 6ms/step - loss: 6.2507e-05 - accuracy: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 10ms/step - loss: 5.9670e-06 - accuracy: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 11ms/step - loss: 8.2662e-04 - accuracy: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.4742e-04 - accuracy: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.1977e-04 - accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0414 - accuracy: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.0918e-04 - accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 10ms/step - loss: 8.8984e-04 - accuracy: 1.0000

# %%
def clean_text(text):
  tokens = nltk.word_tokenize(text)
  tokens = [lemmatizer.lemmatize(word) for word in tokens]
  return tokens

def bag_of_words(text, vocab):
  tokens = clean_text(text)
  bow = [0] * len(vocab)
  for w in tokens:
    for idx, word in enumerate(vocab):
      if word == w:
        bow[idx] = 1
  return np.array(bow)

def pred_class(text, vocab, labels):
  bow = bag_of_words(text, vocab)
  result = model.predict(np.array([bow]))[0]
  thresh = 0.2
  y_pred = [[idx, res] for idx, res in enumerate(result) if res > thresh]

  y_pred.sort(key = lambda x: x[1], reverse = True)
  return_list = []
  for r in y_pred:
    return_list.append(labels[r[0]])
  return return_list

def get_response(intents_list, intents_json):
  tag = intents_list[0]
  list_of_intents = intents_json['intents']
  for i in list_of_intents:
    if i['tag'] == tag:
      result = random.choice(i['responses'])
      break
  return result

# %%
while True:
  message = input('')
  intents = pred_class(message, words, classes)
  result = get_response(intents, data)
  print('Bot -> '+ result)
# Out:
# hi
# Chatbot -> How are you doing?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     624         """
# --> 625         parts = [self.recv(flags, copy=copy, track=track)]
#     626         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-8f6bcd5a313e> in <module>()
#       1 while True:
# ----> 2   message = input('')
#       3   intents = pred_class(message, words, classes)
#       4   result = get_response(intents, data)
#       5   print('Chatbot -> '+ result)
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:
